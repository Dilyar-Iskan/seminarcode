# %% [markdown]
# # Tasks:
#
# - Upgrade the ```data/log_generator.py``` from PyProM to Pm4Py.
#
# - currently: working on log generator
#
# - Focus on replication of the experimental results:
# - important my own example.
# - Focus on application:
# - Focus on running example:
# - Include new datasets (for real) and generate new dataset (arrtifical)
# - find the limitations of the approach.

# %% [markdown]
# ## How does the evaluation work?
#
#
# - The ```.sh``` bash files generate the results for the paper.
#
# - ```./visualize/``` contains the code to generate the figures.
#
# - Fig. 7 b) is generated by ```./visualize/exp1.py```
#
# - Fig. 7 a) is generated by unknown. However, the numbers for basline are 7567, 14917, 28393, 41371. The sources for suggested are unknown.

# %% [markdown]
# # Suggested Method:
# TODO: explain the suggested method from the paper and apply the resutls in the conde.

# %% [markdown]
# ## overview:

# %% [markdown]
# ### 1: Construction of offline prediction model.
# - (Remaining) Processing Time
# - Next Activity
# of onging instances (Traces)
#
# Dataset(Original?): ```./sample_data/real/modi_BPI_2012_dropna_filter_act.csv```
# Dataset(Preprocessed for training): ```./prediction/training_data.csv```
#
#
# TODO: check the origin of the dataset and the file ```./data/preprocess.py```

# %% [markdown]
# ### 2: Time & Next Activity Prediction

# %% [markdown]
# ### 3: Resource Scheduling

# %% [markdown]
# ### 4: Execution:

# %% [markdown]
# UNTIL TOMMOROW:
# - [ ] check the results in the evaluation section for the suggested method.
# - [ ] check the results in the evaluation section for the baseline method.

# %% [markdown]
# # Deliverables:
#
# - [ ] 1. Produce Code preferably in jupyter notebook.
# - [ ] 2. Replicate experiments
# - [ ] 3. Paper
# - [ ] 4. Presentation (look up the slides)

# %% [markdown]
# # Unclear claims made in the paper:
#
# ## Point 1:
# In Evaluation of real-life event log, a claim has been made that
#
# ```
# We build an event log from the dataset by filtering it to
# include the events before 10/3/2012 and use it as an input
# of phase 1 in our method.
# ```
#
# However, the dataset `./prediction/training_data.csv` is not filtered and it includes the dates after 10/3/2012 as well.

# %% [markdown]
# ## Point 2:
# In Evaluation of real-life event log, a claim has been made that
#
# ```
#  The instances and resources, who
# appear on 10/3/2012 in the dataset, are extracted from the
# dataset, and they become components of the event stream
# which we use in phase 2.
# ```
# However, the dataset `./sample_data/real/modi_BPI_2012_2012-03-10.csv` is not filtered again and it includes data from earlier dates as well.

# %% [markdown]
# Point 3:
# In Evaluation of real-life event log, a claim has been made that
#
# ```
# From the prediction model and the event
# stream, we simulate the resource allocation on 10/3/2012.
# Table II shows the results from both baseline approach and
# our proposed method. The total weighted completion time of
# baseline approach (i.e., 1,479) is 42 percent higher than the one
# of our suggested method (i.e., 1038).
# ```
#
# | 2012-03-10  |     Baseline      |    Suggested       |
# | :---        |    :----:   |          ---: |
# |    Dilyar Iskan        | 1598 (8.99 sec)       | 1540 (241.5)   |
# |   Paper                | 1479     (7.6)   | 1038 (115.6)     |
# |  results from the code of the paper     | 1590, 1598     (28.16, 18.56 )   | 1598, 1540  (316.60, 318.67 )     |

# %% [markdown]
# # COUNTER EXAMPLE:
